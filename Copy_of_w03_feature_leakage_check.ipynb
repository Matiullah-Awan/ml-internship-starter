# %% [markdown]
# <a href="https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/Copy_of_w03_feature_leakage_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %% [markdown]
# Buliding a clean feature vector for M.Minhas Watches using a past visitors and page view metrices while stricly keeping future order label outside the feature set to prevent leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
data={'Date':['2026-07-18','2026-07-19'],'Visitors':[2,5],'Page Views':[8,15],'Orders':[0,1]}
df=pd.DataFrame(data)
X=df[['Visitors','Page Views']]
y=df['Orders']
print("Feature Vector(x):\n",X)
print("Target Label(y):\n",y)
print("Leakage Checked Passed: Feature donot contain target labels.")
# Out:
# Feature Vector(x):
#     Visitors  Page Views
# 0         2           8
# 1         5          15
# Target Label(y):
#  0    0
# 1    1
# Name: Orders, dtype: int64
# Leakage Checked Passed: Feature donot contain target labels.

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %% [markdown]
# **Visitors:**Count of unique store visitors no missing values available before prediction.
# **Page Views:**Total views on store pages no missing values available before prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
data={'Date':['2026-07-18','2026-07-19'],'Visitors':[2,5],'Page Views':[8,15],'Orders':[0,1]}
df=pd.DataFrame(data)
print("Missing values in feature:\n",X.isnull().sum())
print("Features summary checked : Available before prediction time.")
# Out:
# Missing values in feature:
#  Visitors      0
# Page Views    0
# dtype: int64
# Features summary checked : Available before prediction time.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %% [markdown]
# Check featuers against labels leakage and future windows . Verified that no target labels or future metrices are included in the feature set.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
leaky_check='Orders'in X.columns
print(f"Is 'Orders' present in features (Leakage Risk)?{leaky_check}")
print("Leakage Hunt Status : Clean. No label-Derived Features Found.")
# Out:
# Is 'Orders' present in features (Leakage Risk)?False
# Leakage Hunt Status : Clean. No label-Derived Features Found.

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %% [markdown]
# Excluded 'Orders' and future aggregrate metrices from features because they cause label leakage and overestimate model performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Exclusion Check Verified: Leaky columns Successfully omitted from feature set.")
# Out:
# Exclusion Check Verified: Leaky columns Successfully omitted from feature set.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [x ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x ] No client names, URLs, or private queries anywhere
# - [x ] My claims use careful words: observed, measured, directional, decision-support
# - [x ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
