# %% [markdown]
# <a href="https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/Copy_of_w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# For Myself managing M.Minhas Watches deciding which watch models to restock we will build a ranking/scoring system from a historical sales and engagement data predicting and scoring demand potential measured by precision@k based a actual sales performance . A wrong call costs wasted capital on slow-moving inventory and missed profit opportunities. A Plain rule is not engagement are too comlex and shifting to map manually. We will claim only decision-support results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Iam predicting a demand potential score for each  watch model . This lab comes from observed outcomes in my store specifically the historical sales volume and customer engagement data like clicks and views that I have already collected.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# My success metric is precision@K. A Good number is defined  as achieving a precision score that exceeds my current manual restocking baseline , meaning more of my top-ranked models are resulting in actual sales compared to my previous restocking decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# My unit of analysis is the daily performance of my store .One row represents one day of store activity ,including metrices like visitors and page views. Currently my base line shows 2 visitors and 8 page views per day. This serves as my starting point to track how restocking decisions might change these number in the future.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
data={'Data':['2026-07-18'],'Visitors':[2],'pageviews':[8],'Order':[0]}
df=pd.DataFrame(data)
print(df)
# Out:
#          Data  Visitors  pageviews  Order
# 0  2026-07-18         2          8      0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A Fixed rule is insufficent because customer demand for watches is not linear.It depends on many signals like day of week trends seasonal spikes and customer intreaction patterns to shift over time . Machine learning is better here because it can automatically detect these complex , tangled relation ships between multiple signals that i cannot write manually in a simple if-statement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [ x] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
