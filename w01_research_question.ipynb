# %% [markdown]
# <a href="https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# I am choosing the freestyle lane. My research question is to analyze the content performance trends to optimize my watch shop's inventory restocking decision.Iam choosing this becauseapplying machine learning to my real-world e-commerence data will help me make data driven decisions and reduce the risk of stocking slow moving item.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/Matiullah-Awan/ml-internship-starter.git
# Out:
# fatal: destination path 'ml-internship-starter' already exists and is not an empty directory.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **1.What decision does this improve?**
# It improves the decision of which watch models to restock to align with customer demand.
# **2.Who acts on the output?**
# I will act on the output by adjustingmy inventory procurement plan for
# 'M.Minhas Watches' based on the predictive performance scores.
# **3.What does a wrong answer Cost?**
# A wrong call results in wasted capital on slow-selling inventory and missed profit opportunities from high-performance models.
# **4.Why does dataor ml help at all?**
# Manual tracking of performance signals is toocomplex given the shifting trends in e-commerence. Ml helps by processing these signals to reveal actionable patterns that simple might miss.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Loading the starter data set reveals the underlying content performance signals like CTR nad engagement rates which are essiential for identifying high-demand items. These real metrices provide the empirical foundation needed to built a robust inventory restoking model over the next 7 weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
df=pd.read_csv('ml-internship-starter/data/raw/content_refresh_anonymized.csv')
print(df.head(3))
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# 2     23643.0  ...     15000-25000  0.09          36.5             0.00
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can claim that my model provides decision-support by highlighting patterns in content performance to guide restoking.I cannot claim casual proof i.e that restocking a specific item definitely causes higher sales or that I am predicting Google's algorithms. My results are directional indicators based on historical data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ x] Every section above is filled — markdown thinking AND the code that backs it
# - [x ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [ x] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
