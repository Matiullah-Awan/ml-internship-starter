# %% [markdown]
# <a href="https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/Copy_of_w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Matiullah-Awan/ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
data={'Data':['2026-07-18'],'Visitors':[2],'page views':[8],'Orders':[0]}
df=pd.DataFrame(data)
print("Row Count:",len(df))
print(df)
# Out:
# Row Count: 1
#          Data  Visitors  page views  Orders
# 0  2026-07-18         2           8       0

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
data={'Data':['2026-07-18'],'Visitors':[2],'page views':[8],'Orders':[0]}
df=pd.DataFrame(data)
print("Verified columns:",list(df.columns))
# Out:
# Verified columns: ['Data', 'Visitors', 'page views', 'Orders']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Missing Values per column:\n",df.isnull().sum())
print("DataFrame shape(Rows,Columns):",df.shape)
# Out:
# Missing Values per column:
#  Data          0
# Visitors      0
# page views    0
# Orders        0
# dtype: int64
# DataFrame shape(Rows,Columns): (1, 4)

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This data can never tell us about offline customer preferences ,why a visitors choose not a buy or competitor pricing strategies on daraz.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Data contract successfully verified for M.Minhas Watches Store.")
# Out:
# Data contract successfully verified for M.Minhas Watches Store.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ x] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [ x] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
